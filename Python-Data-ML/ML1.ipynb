# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd

# %%
data = pd.read_csv("/content/drive/My Drive/PyDataML/vote.csv")
data
# Out:
#      gender  region  edu  ...  score_intention  vote  parties
# 0         1       4    3  ...              4.0     1        2
# 1         1       5    2  ...              3.0     0        3
# 2         1       3    1  ...              2.8     1        4
# 3         2       1    2  ...              2.6     1        1
# 4         1       1    1  ...              2.4     1        1
# ..      ...     ...  ...  ...              ...   ...      ...
# 206       1       4    1  ...              1.8     1        2
# 207       1       1    2  ...              2.6     1        4
# 208       1       2    2  ...              2.6     1        2
# 209       1       1    2  ...              4.0     1        4
# 210       2       1    2  ...              3.8     1        2
#
# [211 rows x 10 columns]

# %%
data.head()
# Out:
#    gender  region  edu  income  ...  score_progress  score_intention  vote  parties
# 0       1       4    3       3  ...               2              4.0     1        2
# 1       1       5    2       3  ...               4              3.0     0        3
# 2       1       3    1       2  ...               3              2.8     1        4
# 3       2       1    2       1  ...               4              2.6     1        1
# 4       1       1    1       2  ...               3              2.4     1        1
#
# [5 rows x 10 columns]

# %%
data.tail()
# Out:
#      gender  region  edu  ...  score_intention  vote  parties
# 206       1       4    1  ...              1.8     1        2
# 207       1       1    2  ...              2.6     1        4
# 208       1       2    2  ...              2.6     1        2
# 209       1       1    2  ...              4.0     1        4
# 210       2       1    2  ...              3.8     1        2
#
# [5 rows x 10 columns]

# %%
data.shape
# Out:
# (211, 10)

# %%
X = data[['gender','region','edu','income','age','score_gov','score_progress','score_intention']]
# X = data[data.columns[0:8]]
# X = data.loc[:, 'gender':'score_intention']

# %%
X.head()
# Out:
#    gender  region  edu  income  age  score_gov  score_progress  score_intention
# 0       1       4    3       3    3          2               2              4.0
# 1       1       5    2       3    3          2               4              3.0
# 2       1       3    1       2    4          1               3              2.8
# 3       2       1    2       1    3          5               4              2.6
# 4       1       1    1       2    4          4               3              2.4

# %%
y1 = data[['vote']]
y2 = data[['parties']]

# %%
y1.head()
# Out:
#    vote
# 0     1
# 1     0
# 2     1
# 3     1
# 4     1

# %%
y2.head()
# Out:
#    parties
# 0        2
# 1        3
# 2        4
# 3        1
# 4        1

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y1, stratify = y1, random_state = 42)

# %%
X_train.head()
# Out:
#     gender  region  edu  ...  score_gov  score_progress  score_intention
# 68       2       4    2  ...          3               3              2.4
# 8        1       2    1  ...          2               2              2.0
# 10       1       1    1  ...          2               4              2.2
# 67       1       4    3  ...          1               2              2.0
# 90       1       1    3  ...          5               2              1.0
#
# [5 rows x 8 columns]

# %%
X_train.shape
# Out:
# (158, 8)

# %%
X_test.head()
# Out:
#     gender  region  edu  ...  score_gov  score_progress  score_intention
# 81       1       3    2  ...          3               3              2.2
# 30       1       1    1  ...          2               2              2.4
# 92       2       1    2  ...          3               4              1.8
# 62       1       1    1  ...          1               1              2.6
# 11       2       4    1  ...          3               2              2.6
#
# [5 rows x 8 columns]

# %%
X_test.shape
# Out:
# (53, 8)

# %%
y_train.head()
# Out:
#     vote
# 68     0
# 8      0
# 10     0
# 67     1
# 90     1

# %%
y_train.shape
# Out:
# (158, 1)

# %%
y_test.head()
# Out:
#     vote
# 81     0
# 30     1
# 92     1
# 62     1
# 11     1

# %%
y_test.shape
# Out:
# (53, 1)

# %%
aa=pd.DataFrame(y_train)
aa['vote'].value_counts(sort=False)
# Out:
# 0     46
# 1    112
# Name: vote, dtype: int64

# %%
y_train.mean()
# Out:
# vote    0.708861
# dtype: float64

# %%
bb=pd.DataFrame(y_test)
bb['vote'].value_counts(sort=False)
# Out:
# 0    15
# 1    38
# Name: vote, dtype: int64

# %%
y_test.mean()
# Out:
# vote    0.716981
# dtype: float64

# %% [markdown]
# # 모델 적용

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
knn = KNeighborsClassifier(n_neighbors=3)

# %%
knn
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#                      metric_params=None, n_jobs=None, n_neighbors=3, p=2,
#                      weights='uniform')

# %%
knn.fit(X_train, y_train)
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   """Entry point for launching an IPython kernel.
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#                      metric_params=None, n_jobs=None, n_neighbors=3, p=2,
#                      weights='uniform')

# %% [markdown]
# # 모델 평가

# %%
pred_train = knn.predict(X_train)

# %%
knn.score(X_train, y_train)
# Out:
# 0.8481012658227848

# %%
pd.crosstab(y_train.vote, pred_train)
# Out:
# col_0   0    1
# vote
# 0      31   15
# 1       9  103

# %%
pred_test=knn.predict(X_test)

# %%
knn.score(X_test, y_test)
# Out:
# 0.5849056603773585

# %%
pd.crosstab(y_test.vote, pred_test)
# Out:
# col_0   0   1
# vote
# 0       4  11
# 1      11  27
