# %%
#1번 과제
#cosmetics_csv 파일을 읽어서 가장 관련성이 높다고 판단되는 
#두가지 항목을 선정하고, 두 항목 사이의 관계를 효율적으로
#표현할 수 있는 시각화 함수를 작성하시오.
#코드 아래부분에 # 표시후 설명문도 넣어주세요.

# %%
import pandas as pd
from pandas import Series, DataFrame

# %%
df = pd.read_csv('cosmetics_.csv')

# %%
df
# Out:
#      gender  marriage  edu  job  mincome  aware  count   amount  decision  \
# 0         1         1    4    1        2      2      1    11000         2
# 1         2         1    4    9        2      1      4    30000         1
# 2         2         2    4    4        3      1      6   100000         3
# 3         2         2    4    7        5      2      6    65000         3
# 4         1         2    6    6        5      2      2    50000         2
# ..      ...       ...  ...  ...      ...    ...    ...      ...       ...
# 242       1         1    4    2        3      2      6     4000         1
# 243       2         2    4    4        2      1     10   150000         3
# 244       2         2    7    8        1      2      3   100000         1
# 245       1         1    4    6        1      3      2    20000         3
# 246       2         2    6   10        1      1     10  1000000         3
#
#      propensity  skin  promo  location  satisf_b  satisf_i  satisf_al  \
# ...

# %%
df.columns
# Out:
# Index(['gender', 'marriage', 'edu', 'job', 'mincome', 'aware', 'count',
#        'amount', 'decision', 'propensity', 'skin', 'promo', 'location',
#        'satisf_b', 'satisf_i', 'satisf_al', 'repurchase'],
#       dtype='object')

# %%
df['gender'].value_counts()
# Out:
# 1    132
# 2    115
# Name: gender, dtype: int64

# %%
df['marriage'].value_counts()
# Out:
# 2    176
# 1     71
# Name: marriage, dtype: int64

# %%
df['edu'].value_counts()
# Out:
# 4    136
# 2     30
# 6     29
# 8     26
# 7     15
# 3      9
# 5      2
# Name: edu, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 247 entries, 0 to 246
# Data columns (total 17 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   gender      247 non-null    int64
#  1   marriage    247 non-null    int64
#  2   edu         247 non-null    int64
#  3   job         247 non-null    int64
#  4   mincome     247 non-null    int64
#  5   aware       247 non-null    int64
#  6   count       247 non-null    int64
#  7   amount      247 non-null    int64
#  8   decision    247 non-null    int64
#  9   propensity  247 non-null    int64
#  10  skin        247 non-null    int64
#  11  promo       247 non-null    int64
#  12  location    247 non-null    int64
#  13  satisf_b    247 non-null    int64
#  14  satisf_i    247 non-null    int64
#  15  satisf_al   247 non-null    int64
#  16  repurchase  247 non-null    int64
# dtypes: int64(17)
# memory usage: 32.9 KB

# %%
df.describe()
# Out:
#            gender    marriage         edu         job     mincome       aware  \
# count  247.000000  247.000000  247.000000  247.000000  247.000000  247.000000
# mean     1.465587    1.712551    4.566802    4.578947    3.757085    3.319838
# std      0.499827    0.453492    1.709191    2.199603    1.674079    5.575692
# min      1.000000    1.000000    2.000000    1.000000    1.000000    1.000000
# 25%      1.000000    1.000000    4.000000    3.000000    2.000000    1.000000
# 50%      1.000000    2.000000    4.000000    4.000000    4.000000    2.000000
# 75%      2.000000    2.000000    6.000000    6.000000    5.000000    2.000000
# max      2.000000    2.000000    8.000000   10.000000    6.000000   31.000000
#
#             count        amount    decision  propensity        skin  \
# count  247.000000  2.470000e+02  247.000000  247.000000  247.000000
# mean     4.327935  1.539393e+05    2.388664    1.975709    2.761134
# ...

# %%
df['count'].describe()
# Out:
# count    247.000000
# mean       4.327935
# std        4.422061
# min        1.000000
# 25%        2.000000
# 50%        3.000000
# 75%        5.000000
# max       36.000000
# Name: count, dtype: float64

# %%
df['amount'].describe()
# Out:
# count    2.470000e+02
# mean     1.539393e+05
# std      3.980750e+05
# min      3.000000e+03
# 25%      3.000000e+04
# 50%      5.200000e+04
# 75%      1.000000e+05
# max      5.000000e+06
# Name: amount, dtype: float64

# %%
df['amount'].describe()
# Out:
# count    2.470000e+02
# mean     1.539393e+05
# std      3.980750e+05
# min      3.000000e+03
# 25%      3.000000e+04
# 50%      5.200000e+04
# 75%      1.000000e+05
# max      5.000000e+06
# Name: amount, dtype: float64

# %%
#그래프 시각화

# %%
import matplotlib.pyplot as plt
df.hist(bins=50, figsize=(20,15))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x00000187F774FA88>,
# ...
#       dtype=object)

# %%
#amount와 count 간 산점도/분포

# %%
import seaborn as sns

# %%
#사분위수를 이용한 이상치 제거
df.quantile()
Q1 = df['amount'].quantile(q=0.25)
Q3 = df['amount'].quantile(q=0.75)
IQR = Q3-Q1
df[(df['amount']<Q3+IQR*1.5)& (df['amount']>Q1-IQR*1.5)]
# Out:
#      gender  marriage  edu  job  mincome  aware  count  amount  decision  \
# 0         1         1    4    1        2      2      1   11000         2
# 1         2         1    4    9        2      1      4   30000         1
# 2         2         2    4    4        3      1      6  100000         3
# 3         2         2    4    7        5      2      6   65000         3
# 4         1         2    6    6        5      2      2   50000         2
# ..      ...       ...  ...  ...      ...    ...    ...     ...       ...
# 241       1         1    2    1        2      2      5    3000         1
# 242       1         1    4    2        3      2      6    4000         1
# 243       2         2    4    4        2      1     10  150000         3
# 244       2         2    7    8        1      2      3  100000         1
# 245       1         1    4    6        1      3      2   20000         3
#
#      propensity  skin  promo  location  satisf_b  satisf_i  satisf_al  \
# ...

# %%
ndf=df.filter(['amount', 'count'])
ndf=ndf[(ndf['count']<10) & (ndf['amount']<500000)]
ndf.hist(bins=50, figsize=(20,15))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x00000187F9715C08>,
# ...
#       dtype=object)

# %%
sns.jointplot(x="amount", y="count", data=ndf, kind="kde", space=0, zorder=0, n_levels=6)
