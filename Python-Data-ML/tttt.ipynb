# %%
import pandas as pd
from pandas import Series, DataFrame

# %%
df = pd.read_csv('cosmetics_.csv')
df
# Out:
#      gender  marriage  edu  job  mincome  aware  count   amount  decision  \
# 0         1         1    4    1        2      2      1    11000         2
# 1         2         1    4    9        2      1      4    30000         1
# 2         2         2    4    4        3      1      6   100000         3
# 3         2         2    4    7        5      2      6    65000         3
# 4         1         2    6    6        5      2      2    50000         2
# ..      ...       ...  ...  ...      ...    ...    ...      ...       ...
# 242       1         1    4    2        3      2      6     4000         1
# 243       2         2    4    4        2      1     10   150000         3
# 244       2         2    7    8        1      2      3   100000         1
# 245       1         1    4    6        1      3      2    20000         3
# 246       2         2    6   10        1      1     10  1000000         3
#
#      propensity  skin  promo  location  satisf_b  satisf_i  satisf_al  \
# ...

# %%
df = pd.read_excel('cosmetics_.xlsx')
df
# Out:
#      gender  marriage  edu  job  mincome  aware  count   amount  decision  \
# 0         1         1    4    1        2      2      1    11000         2
# 1         2         1    4    9        2      1      4    30000         1
# 2         2         2    4    4        3      1      6   100000         3
# 3         2         2    4    7        5      2      6    65000         3
# 4         1         2    6    6        5      2      2    50000         2
# ..      ...       ...  ...  ...      ...    ...    ...      ...       ...
# 242       1         1    4    2        3      2      6     4000         1
# 243       2         2    4    4        2      1     10   150000         3
# 244       2         2    7    8        1      2      3   100000         1
# 245       1         1    4    6        1      3      2    20000         3
# 246       2         2    6   10        1      1     10  1000000         3
#
#      propensity  skin  promo  location  satisf_b  satisf_i  satisf_al  \
# ...

# %%
df = pd.read_csv('cosmeticsKR_.csv', encoding='euc-kr')
df
# Out:
#      성별  결혼여부  교육  직업  소득  인지브랜드  구매량     구매금액  의사결정자  선호성향  스킨  프로모션  구매장소  \
# 0     1     1   4   1   2      2    1    11000      2     1   1     1     2
# 1     2     1   4   9   2      1    4    30000      1     1   3     2     3
# 2     2     2   4   4   3      1    6   100000      3     2   3     2     2
# 3     2     2   4   7   5      2    6    65000      3     2   5     2     3
# 4     1     2   6   6   5      2    2    50000      2     2   3     2     3
# ..   ..   ...  ..  ..  ..    ...  ...      ...    ...   ...  ..   ...   ...
# 242   1     1   4   2   3      2    6     4000      1     1   1     1     4
# 243   2     2   4   4   2      1   10   150000      3     2   2     1     2
# 244   2     2   7   8   1      2    3   100000      1     2   1     1     5
# 245   1     1   4   6   1      3    2    20000      3     1   1     1     3
# 246   2     2   6  10   1      1   10  1000000      3     2   3     1     3
#
#      만족1  만족2  전반만족  재구매의향
# 0      5    2     2      2
# ...

# %%
df.head()
# Out:
#    성별  결혼여부  교육  직업  소득  인지브랜드  구매량    구매금액  의사결정자  선호성향  스킨  프로모션  구매장소  만족1  \
# 0   1     1   4   1   2      2    1   11000      2     1   1     1     2    5
# 1   2     1   4   9   2      1    4   30000      1     1   3     2     3    2
# 2   2     2   4   4   3      1    6  100000      3     2   3     2     2    4
# 3   2     2   4   7   5      2    6   65000      3     2   5     2     3    3
# 4   1     2   6   6   5      2    2   50000      2     2   3     2     3    3
#
#    만족2  전반만족  재구매의향
# 0    2     2      2
# 1    3     3      4
# 2    5     4      4
# 3    4     4      4
# 4    3     3      3

# %%
df.tail()
# Out:
#      성별  결혼여부  교육  직업  소득  인지브랜드  구매량     구매금액  의사결정자  선호성향  스킨  프로모션  구매장소  \
# 242   1     1   4   2   3      2    6     4000      1     1   1     1     4
# 243   2     2   4   4   2      1   10   150000      3     2   2     1     2
# 244   2     2   7   8   1      2    3   100000      1     2   1     1     5
# 245   1     1   4   6   1      3    2    20000      3     1   1     1     3
# 246   2     2   6  10   1      1   10  1000000      3     2   3     1     3
#
#      만족1  만족2  전반만족  재구매의향
# 242    2    1     1      1
# 243    3    4     4      4
# 244    2    5     4      4
# 245    4    3     3      2
# 246    2    3     3      3

# %%
df[100:150]
# Out:
#      성별  결혼여부  교육  직업  소득  인지브랜드  구매량    구매금액  의사결정자  선호성향  스킨  프로모션  구매장소  \
# 100   1     2   8   3   6      2    3  100000      3     2   3     2     3
# 101   2     1   4   8   1      1    2  100000      3     2   3     2     3
# 102   2     2   4   7   4      2    5   30000      3     2   5     2     2
# 103   2     2   2   7   3      2    2  100000      3     2   3     2     3
# 104   2     2   8   3   6      2    2  300000      3     3   5     2     1
# 105   1     2   6   2   6      2    2   20000      3     1   1     2     1
# 106   2     2   6   4   3      2    3  150000      2     3   2     3     5
# 107   2     1   4   4   2      1    2   30000      3     1   3     2     2
# 108   2     2   4   3   3      1    3  250000      2     2   5     1     1
# 109   2     2   4   5   5      8    3  200000      3     1   4     2     1
# 110   2     2   2   4   4      5    3  250000      1     2   2     3     5
# ...

# %%
df[:25]
# Out:
#     성별  결혼여부  교육  직업  소득  인지브랜드  구매량     구매금액  의사결정자  선호성향  스킨  프로모션  구매장소  \
# 0    1     1   4   1   2      2    1    11000      2     1   1     1     2
# 1    2     1   4   9   2      1    4    30000      1     1   3     2     3
# 2    2     2   4   4   3      1    6   100000      3     2   3     2     2
# 3    2     2   4   7   5      2    6    65000      3     2   5     2     3
# 4    1     2   6   6   5      2    2    50000      2     2   3     2     3
# 5    2     2   2   7   3      1    2   100000      2     1   4     2     3
# 6    2     1   6   4   5      1    5   100000      3     2   5     2     3
# 7    1     1   6   4   5      4   10    39000      3     2   2     1     2
# 8    2     2   4   5   2      2    2    40000      3     2   3     2     3
# 9    2     2   4   5   2      1    2   100000      3     3   3     1     3
# 10   2     1   7   4   3     10    3    50000      1     3   1     2     3
# ...

# %%
df[200:]
# Out:
#      성별  결혼여부  교육  직업  소득  인지브랜드  구매량     구매금액  의사결정자  선호성향  스킨  프로모션  구매장소  \
# 200   1     2   2   6   1     15    1    10000      3     2   4     3     3
# 201   1     1   5   8   1      2    5    40000      3     1   4     2     3
# 202   2     2   4   4   2      2    2   470000      2     1   1     2     3
# 203   2     1   4   2   3      1   10   100000      2     3   3     4     1
# 204   1     1   3   8   1      2    4    30000      3     2   5     2     3
# 205   1     2   6   3   6      2    3    50000      3     2   3     2     3
# 206   2     2   4   7   6      1   10    50000      3     3   5     2     1
# 207   1     2   6   2   6      2    3   150000      2     2   3     2     3
# 208   2     1   6   4   3      2    6   200000      3     3   1     2     1
# 209   2     2   4   7   1      2    2    70000      3     2   3     1     3
# 210   2     1   7   8   2      2    5    35000      3     2   1     2     2
# ...

# %%
df = pd.read_csv('cosmetics_.csv')

# %%
df.amount
# Out:
# 0        11000
# 1        30000
# 2       100000
# 3        65000
# 4        50000
#         ...
# 242       4000
# 243     150000
# 244     100000
# 245      20000
# 246    1000000
# Name: amount, Length: 247, dtype: int64

# %%
df[df.columns[[1,3,10]]]
# Out:
#      marriage  job  skin
# 0           1    1     1
# 1           1    9     3
# 2           2    4     3
# 3           2    7     5
# 4           2    6     3
# ..        ...  ...   ...
# 242         1    2     1
# 243         2    4     2
# 244         2    8     1
# 245         1    6     1
# 246         2   10     3
#
# [247 rows x 3 columns]

# %%
df.loc[:, 'decision':'location']
# Out:
#      decision  propensity  skin  promo  location
# 0           2           1     1      1         2
# 1           1           1     3      2         3
# 2           3           2     3      2         2
# 3           3           2     5      2         3
# 4           2           2     3      2         3
# ..        ...         ...   ...    ...       ...
# 242         1           1     1      1         4
# 243         3           2     2      1         2
# 244         1           2     1      1         5
# 245         3           1     1      1         3
# 246         3           2     3      1         3
#
# [247 rows x 5 columns]

# %%
df.iloc[1:5, 4:8]
# Out:
#    mincome  aware  count  amount
# 1        2      1      4   30000
# 2        3      1      6  100000
# 3        5      2      6   65000
# 4        5      2      2   50000

# %%
df
# Out:
#      gender  marriage  edu  job  mincome  aware  count   amount  total price  \
# 0         1         1    4    1        2      2      1    11000       132000
# 1         2         1    4    9        2      1      4    30000       360000
# 2         2         2    4    4        3      1      6   100000      1200000
# 3         2         2    4    7        5      2      6    65000       780000
# 4         1         2    6    6        5      2      2    50000       600000
# ..      ...       ...  ...  ...      ...    ...    ...      ...          ...
# 242       1         1    4    2        3      2      6     4000        48000
# 243       2         2    4    4        2      1     10   150000      1800000
# 244       2         2    7    8        1      2      3   100000      1200000
# 245       1         1    4    6        1      3      2    20000       240000
# 246       2         2    6   10        1      1     10  1000000     12000000
#
# ...

# %%
df.at[4, 'amount']
# Out:
# 50000

# %%
df_columns = df.copy()

# %%
df_columns = df_columns[['gender','marriage','edu','job','mincome']]
df_columns.head()
# Out:
#    gender  marriage  edu  job  mincome
# 0       1         1    4    1        2
# 1       2         1    4    9        2
# 2       2         2    4    4        3
# 3       2         2    4    7        5
# 4       1         2    6    6        5

# %%
df_columns.rename(columns={'job':'occupation'}, inplace=True)
df_columns[0:7]
# Out:
#    gender  marriage  edu  occupation  mincome
# 0       1         1    4           1        2
# 1       2         1    4           9        2
# 2       2         2    4           4        3
# 3       2         2    4           7        5
# 4       1         2    6           6        5
# 5       2         2    2           7        3
# 6       2         1    6           4        5

# %%
df['tex-included price'] = df['amount']*1.1

# %%
df[1, 'total price'].sum()
# Out:
# 360000
